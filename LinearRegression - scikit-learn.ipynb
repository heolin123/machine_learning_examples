# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

# %%
http://www.datarobot.com/blog/classification-with-scikit-learn/
# Out:
#   File "<ipython-input-19-a90d51cfdd1c>", line 1
#     http://www.datarobot.com/blog/classification-with-scikit-learn/
#         ^
# SyntaxError: invalid syntax

# %%
# Load the diabetes dataset
diabetes = datasets.load_diabetes()


# Use only one feature
diabetes_X = diabetes.data[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(diabetes_X_test, diabetes_y_test))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, regr.predict(diabetes_X_test), color='blue',
         linewidth=3)

plt.show()
# Out:
# ('Coefficients: \n', array([ 938.23786125]))
# Residual sum of squares: 2548.07
# Variance score: 0.47
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#prepare data
n = 50
theta_target = np.array([-63, 665]).reshape(2, 1)

E=np.random.normal(0, 86, n).reshape(n, 1)
X=np.ones(shape=(n, 2))
X[:, 0]=np.arange(n)
YA=X.dot(theta_target)
Y=X.dot(theta_target)+E

#fit curve
x = X[:, 0].reshape(n, 1)
est = LinearRegression()
est.fit(x, Y)
coefs = np.array([est.coef_[0][0], est.intercept_[0]])

#plot results
pylab.plot(X[:, 0], Y, 'o')
pylab.plot(x, np.dot(X, coefs))
pylab.plot(X[:, 0], Y-E, 'k-', color='red')
pylab.show()

# %%
#prepare data
numbers = 100
density = 5
n = numbers * density
theta_target = np.array([-63, 665]).reshape(2, 1)

E=np.random.normal(0, 86, n).reshape(n, 1)
X=np.ones(shape=(n, 2))
X[:, 0]=np.linspace(0, numbers, num=n)
Y=X.dot(theta_target)
sin = np.sin(X[:, 0]).reshape(n, 1)*1
Y1 = Y + sin


x = X[:, 0].reshape(n, 1)
est = LinearRegression()
est.fit(x, Y)
coefs = np.array([est.coef_[0][0], est.intercept_[0]])


pylab.plot(X[:, 0], Y1, 'o')
pylab.plot(x, np.dot(X, coefs))
pylab.show()

# %%
print coefs
R = np.dot(X, theta_target).reshape(n, 1)
Y0 = Y1 - R
pylab.plot(Y0)
pylab.show()
# Out:
# [ -63.  665.]
# 500
# 500
